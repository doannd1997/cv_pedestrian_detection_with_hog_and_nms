# %%
import os
import numpy as np
import cv2
from pathlib import Path
import glob

# %%
prefix_path = "dataset"
neg_in_paths = [
    "inria_pedestrian/Test/neg",
    "inria_pedestrian/Train/neg"
]
pos_in_paths = [
    "inria_pedestrian/pos_0/tmp",
    "inria_pedestrian/pos_1/tmp"
]
neg_out_path = "human_neg"
pos_out_path = "human_pos"

# %%
def clean_resize_and_crop_destination_folder():
    neg_files = glob.glob(os.path.join(prefix_path, neg_out_path) + "/*")
    for file in neg_files:
        os.remove(file)
        
    pos_files = glob.glob(os.path.join(prefix_path, pos_out_path) + "/*")
    for file in pos_files:
        os.remove(file)

# %%
# height - width
expected_size = (80, 40)
ratio_h_w = expected_size[0]/expected_size[1]

# crop and resize image from input and save to output
def resize_and_crop(in_path="", out_path=""):
    files_out = glob.glob(out_path + "*")
    
    _, _, files_in = next(os.walk(in_path))
    files_in = [os.path.join(in_path, file) for file in files_in]
    for c, file in enumerate(files_in):
        file = file.replace("\\", "/")
        img = cv2.imread(file)
        if img is None:
            print("format error! {file_name}".format_map({"file_name": file}))
            continue
        
        crop_w = w = img.shape[1]
        crop_h = h = img.shape[0]
        if h/w > ratio_h_w:
            crop_h = int(w * ratio_h_w)
        else:
            if h/w < ratio_h_w:
                crop_w = int(h // ratio_h_w)
                
        w0 = int((w-crop_w)//2) if crop_w <= w else 0
        h0 = int((h-crop_h)//2) if crop_h <= h else 0
        crop_img = img[h0:h0+crop_h, w0:w0+crop_w]
        crop_img = cv2.resize(crop_img, tuple(reversed(expected_size)))
        
        cv2.imwrite(os.path.join(out_path, str(len(files_out) + c) + ".png"), crop_img)

# %%
def refine_execute():
    clean_resize_and_crop_destination_folder()
    
    for nip in neg_in_paths:
        neg_in_path = os.path.join(prefix_path, nip)
        resize_and_crop(in_path=neg_in_path, out_path=os.path.join(prefix_path, neg_out_path))
    
    for pip in pos_in_paths:
        pos_in_path = os.path.join(prefix_path, pip)
        resize_and_crop(in_path=pos_in_path, out_path=os.path.join(prefix_path, pos_out_path))

# %%
is_neg_in_empty = len(glob.glob(os.path.join(prefix_path, neg_out_path) + "/*")) == 0
is_pos_in_empty = len(glob.glob(os.path.join(prefix_path, pos_out_path) + "/*")) == 0
if is_neg_in_empty or is_pos_in_empty:
    clean_resize_and_crop_destination_folder()
    refine_execute()
# Out:
# format error! dataset/inria_pedestrian/pos_0/tmp/100.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1000.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1003.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1004.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1007.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1008.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1009.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1014.png
# format error! dataset/inria_pedestrian/pos_0/tmp/102.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1064.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1065.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1073.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1074.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1091.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1092.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1093.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1094.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1098.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1112.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1130.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1131.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1132.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1133.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1134.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1136.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1145.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1147.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1148.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1149.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1161.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1165.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1166.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1167.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1169.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1200.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1202.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1203.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1204.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1205.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1206.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1216.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1217.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1221.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1231.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1250.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1251.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1252.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1253.png
# format error! dataset/inria_pedestrian/pos_0/tmp/126.png
# format error! dataset/inria_pedestrian/pos_0/tmp/128.png
# format error! dataset/inria_pedestrian/pos_0/tmp/129.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1294.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1295.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1296.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1297.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1313.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1341.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1342.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1348.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1349.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1352.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1353.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1365.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1385.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1386.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1387.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1388.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1391.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1396.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1397.png
# format error! dataset/inria_pedestrian/pos_0/tmp/14.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1403.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1404.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1427.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1428.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1431.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1432.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1445.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1461.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1462.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1464.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1465.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1466.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1470.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1472.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1473.png
# format error! dataset/inria_pedestrian/pos_0/tmp/15.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1505.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1506.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1528.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1556.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1562.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1565.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1566.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1567.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1569.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1570.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1571.png
# format error! dataset/inria_pedestrian/pos_0/tmp/159.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1595.png
# format error! dataset/inria_pedestrian/pos_0/tmp/16.png
# format error! dataset/inria_pedestrian/pos_0/tmp/160.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1613.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1614.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1615.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1646.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1668.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1669.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1672.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1679.png
# format error! dataset/inria_pedestrian/pos_0/tmp/168.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1680.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1695.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1697.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1698.png
# format error! dataset/inria_pedestrian/pos_0/tmp/170.png
# format error! dataset/inria_pedestrian/pos_0/tmp/171.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1736.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1737.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1739.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1745.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1746.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1751.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1753.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1754.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1760.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1761.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1786.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1787.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1826.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1830.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1866.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1867.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1912.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1913.png
# format error! dataset/inria_pedestrian/pos_0/tmp/192.png
# format error! dataset/inria_pedestrian/pos_0/tmp/193.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1930.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1934.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1935.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1936.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1961.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1963.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1973.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1979.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1980.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1983.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1985.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1986.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1987.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1988.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1989.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1990.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1991.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1992.png
# format error! dataset/inria_pedestrian/pos_0/tmp/1993.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2005.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2007.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2015.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2021.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2022.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2028.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2039.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2069.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2070.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2074.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2075.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2076.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2077.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2078.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2079.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2080.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2081.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2083.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2086.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2087.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2088.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2089.png
# format error! dataset/inria_pedestrian/pos_0/tmp/209.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2090.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2091.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2092.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2093.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2094.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2096.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2097.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2098.png
# format error! dataset/inria_pedestrian/pos_0/tmp/21.png
# format error! dataset/inria_pedestrian/pos_0/tmp/210.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2105.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2108.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2109.png
# format error! dataset/inria_pedestrian/pos_0/tmp/211.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2121.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2122.png
# format error! dataset/inria_pedestrian/pos_0/tmp/213.png
# format error! dataset/inria_pedestrian/pos_0/tmp/214.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2141.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2142.png
# format error! dataset/inria_pedestrian/pos_0/tmp/215.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2159.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2178.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2179.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2187.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2188.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2189.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2190.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2194.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2217.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2256.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2257.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2258.png
# format error! dataset/inria_pedestrian/pos_0/tmp/229.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2314.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2315.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2334.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2335.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2336.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2337.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2338.png
# format error! dataset/inria_pedestrian/pos_0/tmp/234.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2340.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2341.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2342.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2343.png
# format error! dataset/inria_pedestrian/pos_0/tmp/236.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2400.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2401.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2402.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2403.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2407.png
# format error! dataset/inria_pedestrian/pos_0/tmp/2408.png
# format error! dataset/inria_pedestrian/pos_0/tmp/26.png
# format error! dataset/inria_pedestrian/pos_0/tmp/267.png
# format error! dataset/inria_pedestrian/pos_0/tmp/268.png
# format error! dataset/inria_pedestrian/pos_0/tmp/269.png
# format error! dataset/inria_pedestrian/pos_0/tmp/27.png
# format error! dataset/inria_pedestrian/pos_0/tmp/276.png
# format error! dataset/inria_pedestrian/pos_0/tmp/277.png
# format error! dataset/inria_pedestrian/pos_0/tmp/278.png
# format error! dataset/inria_pedestrian/pos_0/tmp/283.png
# format error! dataset/inria_pedestrian/pos_0/tmp/284.png
# format error! dataset/inria_pedestrian/pos_0/tmp/289.png
# format error! dataset/inria_pedestrian/pos_0/tmp/291.png
# format error! dataset/inria_pedestrian/pos_0/tmp/308.png
# format error! dataset/inria_pedestrian/pos_0/tmp/379.png
# format error! dataset/inria_pedestrian/pos_0/tmp/39.png
# format error! dataset/inria_pedestrian/pos_0/tmp/398.png
# format error! dataset/inria_pedestrian/pos_0/tmp/399.png
# format error! dataset/inria_pedestrian/pos_0/tmp/4.png
# format error! dataset/inria_pedestrian/pos_0/tmp/40.png
# format error! dataset/inria_pedestrian/pos_0/tmp/405.png
# format error! dataset/inria_pedestrian/pos_0/tmp/407.png
# format error! dataset/inria_pedestrian/pos_0/tmp/408.png
# format error! dataset/inria_pedestrian/pos_0/tmp/409.png
# format error! dataset/inria_pedestrian/pos_0/tmp/410.png
# format error! dataset/inria_pedestrian/pos_0/tmp/411.png
# format error! dataset/inria_pedestrian/pos_0/tmp/413.png
# format error! dataset/inria_pedestrian/pos_0/tmp/414.png
# format error! dataset/inria_pedestrian/pos_0/tmp/415.png
# format error! dataset/inria_pedestrian/pos_0/tmp/416.png
# format error! dataset/inria_pedestrian/pos_0/tmp/417.png
# format error! dataset/inria_pedestrian/pos_0/tmp/440.png
# format error! dataset/inria_pedestrian/pos_0/tmp/441.png
# format error! dataset/inria_pedestrian/pos_0/tmp/446.png
# format error! dataset/inria_pedestrian/pos_0/tmp/466.png
# format error! dataset/inria_pedestrian/pos_0/tmp/470.png
# format error! dataset/inria_pedestrian/pos_0/tmp/471.png
# format error! dataset/inria_pedestrian/pos_0/tmp/472.png
# format error! dataset/inria_pedestrian/pos_0/tmp/473.png
# format error! dataset/inria_pedestrian/pos_0/tmp/474.png
# format error! dataset/inria_pedestrian/pos_0/tmp/475.png
# format error! dataset/inria_pedestrian/pos_0/tmp/483.png
# format error! dataset/inria_pedestrian/pos_0/tmp/484.png
# format error! dataset/inria_pedestrian/pos_0/tmp/485.png
# format error! dataset/inria_pedestrian/pos_0/tmp/486.png
# format error! dataset/inria_pedestrian/pos_0/tmp/488.png
# format error! dataset/inria_pedestrian/pos_0/tmp/492.png
# format error! dataset/inria_pedestrian/pos_0/tmp/493.png
# format error! dataset/inria_pedestrian/pos_0/tmp/496.png
# format error! dataset/inria_pedestrian/pos_0/tmp/5.png
# format error! dataset/inria_pedestrian/pos_0/tmp/537.png
# format error! dataset/inria_pedestrian/pos_0/tmp/540.png
# format error! dataset/inria_pedestrian/pos_0/tmp/541.png
# format error! dataset/inria_pedestrian/pos_0/tmp/542.png
# format error! dataset/inria_pedestrian/pos_0/tmp/543.png
# format error! dataset/inria_pedestrian/pos_0/tmp/568.png
# format error! dataset/inria_pedestrian/pos_0/tmp/585.png
# format error! dataset/inria_pedestrian/pos_0/tmp/587.png
# format error! dataset/inria_pedestrian/pos_0/tmp/588.png
# format error! dataset/inria_pedestrian/pos_0/tmp/6.png
# format error! dataset/inria_pedestrian/pos_0/tmp/616.png
# format error! dataset/inria_pedestrian/pos_0/tmp/617.png
# format error! dataset/inria_pedestrian/pos_0/tmp/633.png
# format error! dataset/inria_pedestrian/pos_0/tmp/635.png
# format error! dataset/inria_pedestrian/pos_0/tmp/638.png
# format error! dataset/inria_pedestrian/pos_0/tmp/639.png
# format error! dataset/inria_pedestrian/pos_0/tmp/647.png
# format error! dataset/inria_pedestrian/pos_0/tmp/648.png
# format error! dataset/inria_pedestrian/pos_0/tmp/65.png
# format error! dataset/inria_pedestrian/pos_0/tmp/66.png
# format error! dataset/inria_pedestrian/pos_0/tmp/662.png
# format error! dataset/inria_pedestrian/pos_0/tmp/663.png
# format error! dataset/inria_pedestrian/pos_0/tmp/664.png
# format error! dataset/inria_pedestrian/pos_0/tmp/665.png
# format error! dataset/inria_pedestrian/pos_0/tmp/7.png
# format error! dataset/inria_pedestrian/pos_0/tmp/727.png
# format error! dataset/inria_pedestrian/pos_0/tmp/728.png
# format error! dataset/inria_pedestrian/pos_0/tmp/729.png
# format error! dataset/inria_pedestrian/pos_0/tmp/730.png
# format error! dataset/inria_pedestrian/pos_0/tmp/772.png
# format error! dataset/inria_pedestrian/pos_0/tmp/787.png
# format error! dataset/inria_pedestrian/pos_0/tmp/788.png
# format error! dataset/inria_pedestrian/pos_0/tmp/789.png
# format error! dataset/inria_pedestrian/pos_0/tmp/791.png
# format error! dataset/inria_pedestrian/pos_0/tmp/792.png
# format error! dataset/inria_pedestrian/pos_0/tmp/793.png
# format error! dataset/inria_pedestrian/pos_0/tmp/798.png
# format error! dataset/inria_pedestrian/pos_0/tmp/799.png
# format error! dataset/inria_pedestrian/pos_0/tmp/825.png
# format error! dataset/inria_pedestrian/pos_0/tmp/826.png
# format error! dataset/inria_pedestrian/pos_0/tmp/844.png
# format error! dataset/inria_pedestrian/pos_0/tmp/846.png
# format error! dataset/inria_pedestrian/pos_0/tmp/851.png
# format error! dataset/inria_pedestrian/pos_0/tmp/852.png
# format error! dataset/inria_pedestrian/pos_0/tmp/920.png
# format error! dataset/inria_pedestrian/pos_0/tmp/921.png
# format error! dataset/inria_pedestrian/pos_0/tmp/922.png
# format error! dataset/inria_pedestrian/pos_0/tmp/923.png
# format error! dataset/inria_pedestrian/pos_0/tmp/924.png
# format error! dataset/inria_pedestrian/pos_0/tmp/934.png
# format error! dataset/inria_pedestrian/pos_0/tmp/94.png
# format error! dataset/inria_pedestrian/pos_0/tmp/962.png
# format error! dataset/inria_pedestrian/pos_0/tmp/963.png
# format error! dataset/inria_pedestrian/pos_0/tmp/964.png
# format error! dataset/inria_pedestrian/pos_0/tmp/965.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001511a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001511b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001522e.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001522f.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001544b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001544c.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001544d.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001549a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001593h.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001607c.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001634b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001638c.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001638d.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001639a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001639b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001639e.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001639f.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001641b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001641c.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001641d.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001641f.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001676a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001676f.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001683c.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001683d.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001688a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001688b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001706a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001718c.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001718d.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001718e.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001718f.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001723a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001723b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001724a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001724b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001724c.png
# format error! dataset/inria_pedestrian/pos_1/tmp/crop001724d.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_039a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_039b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_055b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_063a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_063b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_075a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_075b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_085b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_087b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_104a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_104b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_115b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_115e.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_115f.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_118a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_118b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_118d.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_120a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_120b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_120c.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_120d.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_127c.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_127d.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_132c.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_132i.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_132j.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_132k.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_132l.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_134e.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_134f.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_135e.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_137c.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_137d.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_137e.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_137g.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_137i.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_137j.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_138c.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_188g.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_188h.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_189d.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_191a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_191e.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_191f.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_193a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_193b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_193c.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_193d.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_204e.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_204f.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_206a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_206b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_207i.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_207j.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_217a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_217b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_217g.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_217h.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_236c.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_236d.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_236g.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_236j.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_250e.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_250f.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_255a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_263e.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_263f.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_263h.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_280a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_280e.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_280f.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_280g.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_280h.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_293a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_293b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_293d.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_303f.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_306a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_306b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_315a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_315b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_315c.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_315d.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_315e.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_315f.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_318a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_318b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_318c.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_318d.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_323a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_323b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_323c.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_323d.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_325a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_325b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_325c.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_325d.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_335a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_335b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_336c.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_337a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_337b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_337c.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_337d.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_337h.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_337i.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_337j.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_347a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_347b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_347c.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_and_bike_006a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_and_bike_006b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_and_bike_012c.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_and_bike_012d.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_and_bike_027a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_and_bike_027b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_and_bike_027c.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_and_bike_027d.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_and_bike_028b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_and_bike_035b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_and_bike_038a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_and_bike_038h.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_and_bike_076d.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_and_bike_092b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_and_bike_136c.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_and_bike_136d.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_and_bike_149a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_and_bike_149b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_and_bike_153a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_and_bike_153b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_and_bike_177a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_and_bike_177b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_and_bike_181a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_and_bike_181b.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_and_bike_188a.png
# format error! dataset/inria_pedestrian/pos_1/tmp/person_and_bike_188b.png
